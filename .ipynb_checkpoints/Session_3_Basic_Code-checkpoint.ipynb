# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kcsra'

# %% [markdown]
# - When we miss the brackets for functions it will give two indications
#      - Function error
#      - bound method

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kcsra'

# %%
import os
os.chdir(r'C:\Users\kcsra\Documents\NareshIT\Python_Sessions')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: C:\Users\kcsra\Documents\NareshIT\Python_Sessions
