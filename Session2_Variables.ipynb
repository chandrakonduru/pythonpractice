# %%
a=10
b=20
a
b
# Out:
# 20

# %%
a=10
b=20
print(a)
print(b)
# Out:
# 10
# 20

# %%
a=10
b=20
a,b
# Out:
# (10, 20)

# %%
a=10
b=20
a,b=30
a,b=40,50
a=60,70
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 a=10
#       2 b=20
# ----> 3 a,b=30
#       4 a,b=40,50
#       5 a=60,70
#
# TypeError: cannot unpack non-iterable int object

# %%
a=60,70  #two values are assigned to one variable. python developers implemented this is an array of elements.

a

# %% [markdown]
# ## Variables:
# Variable changes the value and also store the values.

# %%
number=100
NUMBER=200
NUMBER
number

# %%
number=100
number123=400
number123

# %%
123number=100
123number

# %%
number123

# %%
number234=500

# %%
number234

# %%
number&one=600
number&one

#The error occurs because you're using an invalid syntax with the ampersand (&) character in a variable name. 
#In Python, variable names can only contain letters, numbers, and underscores, and cannot start with a number.

# %%
number$one=400
number$one

# %%
number_one=500
number_one

# %%
_=600
_

# %%
number one=500
number one

# %%
name=chandra
name

# %%
name='chandra'
name

# %% [markdown]
# ## Do not use in built functions for variable names even if it works
# Ex:
# sum()
#
# min()
#
# max()

# %%
len=100
len

# %%
sum=100
sum

# %% [markdown]
# ### Do not use reserved keywords like if conditions for variable names:

# %%
sum=100
if=200
name=chandra
name='chandra'
# Out:
#   Cell In[36], line 2
#     if=200
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# - Variables can be  **upper case or lower case**
#      - number=100 or NUMBER=200
# - Variables are **case sensitive**
# - Variable can allow **number as suffix**
# - Variables cannot allow **special characters**
# - Variables can allow only **underscore**
# - Variables cannot be **reserved keywords**
# - Variables can have **inbuilt functions** but not recomended
# -

# %%
n1=100
type(n1)
# Out:
# int

# %%
n2=100.5
type(n2)
# Out:
# float

# %% [markdown]
# **Exponential Data**

# %%
1e+1
# Out:
# 10.0
