# %%
1+1
# Out:
# 2

# %%
a=20
b=10
c=a+b
c
# Out:
# 30

# %% [markdown]
# Testing

# %%
number
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 number
#
# NameError: name 'number' is not defined

# %%
number=100
number

# %%
n1=300

# %%
n1

# %%
# code cell indicates square bracket before cell
# if the square bracket is empty , then it means that the cell did not run
#when we run the cell, there is number available in square bracket

# %% [markdown]
# # Kernel:
# - Kernel White:
# idle state
# - Kernel black:
# it is busy. the square bracket will have [*] symbol which says that this cell is running.
# - Kernal red:
# dead state. it means some issue, we need to restart
# - code mode to markdown mode:
# Esc+m
# - markdown mode to code mode:
# Esc+y

# %%
print('good morning')

# %%
import time
time.sleep(100)
print('good morning')

# %% [markdown]
# ## In order to import an image, we need to copy the html of that image and paste it here with markdown mode

# %% [markdown]
# <img src="https://incubator.ucf.edu/wp-content/uploads/2023/07/artificial-intelligence-new-technology-science-futuristic-abstract-human-brain-ai-technology-cpu-central-processor-unit-chipset-big-data-machine-learning-cyber-mind-domination-generative-ai-scaled-1-1500x1000.jpg" jsaction="" class="sFlh5c FyHeAf iPVvYb" style="max-width: 1500px; height: 202px; margin: 0px; width: 303px;" alt="What is Artificial Intelligence (AI) and Why People Should Learn About it -  UCF Business Incubation Program - University of Central Florida" jsname="kn3ccd">
