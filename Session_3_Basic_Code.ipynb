# %%
import os

# %%
os.getcwd
# Out:
# <function nt.getcwd()>

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kcsra'

# %% [markdown]
# - When we miss the brackets for functions it will give two indications
#      - Function error
#      - bound method

# %%
os.getcwd()
# Out:
# 'C:\\Users\\kcsra'

# %%
import os
os.chdir(r'C:\Users\kcsra\Documents\NareshIT\Python_Sessions')
print(f"Current working directory: {os.getcwd()}")
# Out:
# Current working directory: C:\Users\kcsra\Documents\NareshIT\Python_Sessions

# %%
# write a program take three numbers and find the average

n1=10
n2=20
n3=30
avg=(n1+n2+n3)/3
avg
# Out:
# 20.0

# %%
pi=3.14
radius=20
area=pi*radius*radius
area
# Out:
# 1256.0

# %%
print(area)
# Out:
# 1256.0

# %%
breadth=1
height=1
length=2
area_right_angle_triangle=0.5*breadth*height
area_right_angle_triangle
# Out:
# 0.5

# %%
area_rectangle=length*breadth
area_rectangle
# Out:
# 2

# %%
round
# Out:
# <function round(number, ndigits=None)>

# %%
round()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 round()
#
# TypeError: round() missing required argument 'number' (pos 1)

# %%
round(3.24)
# Out:
# 3

# %%
round(9.9576795678,2)
# Out:
# 9.96

# %% [markdown]
# # Data Types
#   - integer: int
#   - float
#   - bool
#   - string:str
#   - list
#   - tuple
#   - dictionary: dict
#   - complex
#   - range
#   - set
#   - frozenset
#   - bytes
#   - bytearray
#   - memoryview
#   - None

# %% [markdown]
# # Python Basics for 2 weeks
# 1. Variables
# 2. Basic Code
# 3. Data Types
# 4. Type Cast
# 5. Eval and input
# 6. Basic codes
# 7. Conditional Statements
# 8. Exception handling
# 9. Functions
# 10. Loops

# %%
n1=100
type(n1)
# Out:
# int

# %%
n2='chandra'
type(n2)
# Out:
# str

# %%
n3=1000.555
type(n3)
# Out:
# float

# %% [markdown]
# # Exponential Data

# %%
1e1 # it can be 1e+1 also
# Out:
# 10.0

# %%
2e+2 #2*100
# Out:
# 200.0

# %%
1e+5 #It can be 1e5 as well which is 1 times 5 zeros 1*100000
# Out:
# 100000.0

# %%
1e+1,1e1
# Out:
# (10.0, 10.0)

# %%
1e+1, 1e-1 #1e-1 means 1 times 1/10=1*(1/10)=0.1
# Out:
# (10.0, 0.1)

# %%
1e/1
# Out:
#   Cell In[35], line 1
#     1e/1
#     ^
# SyntaxError: invalid decimal literal

# %%
1e*1
# Out:
#   Cell In[36], line 1
#     1e*1
#     ^
# SyntaxError: invalid decimal literal

# %%
name='chandra'
name
# Out:
# 'chandra'

# %%
name1="chandra"
name1
# Out:
# 'chandra'

# %%
print(name1)
# Out:
# chandra

# %%
s1='hello'
len(s1)
# Out:
# 5

# %%
s2='hello   '
len(s2)
# Out:
# 8

# %%
s1,s2
# Out:
# ('hello', 'hello   ')

# %%
print(s1)
print(s2)
# Out:
# hello
# hello

# %%
print("I like 'python'")
# Out:
# I like 'python'

# %%
print(' I like "python"')
# Out:
#  I like "python"

# %% [markdown]
# - Strings can be **single quotes**
# - Strings can be **double quotes**
# - Python by default use **single quotes** only
# - when print the string we need to be very careful, refer to print(s1), print(s2) example
# - If we want to highlight any word, then keep entire string in $single$ $quotes$ and highlight the word in $double$ $quotes$. we can do viceversa as well

# %% [markdown]
# # Doc String

# %%
"hello how are you
i'm good"
# Out:
#   Cell In[47], line 1
#     "hello how are you
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
'hello how are you
i'm good'
# Out:
#   Cell In[48], line 1
#     'hello how are you
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"""hello how are you
i'm good"""
# Out:
# "hello how are you\ni'm good"

# %% [markdown]
# - but triple quotes are not recomended.
# - triple quotes are used to communicate the information.
# - if any user writing triple quotes, it is more of communicating to the user. In Vs code, we don't have markdown option, so it is sometimes used for that. It is famously called as **DocString**

# %%
import os
os.getcwd() #click on shift+tab
# Out:
# 'C:\\Users\\kcsra\\Documents\\NareshIT\\Python_Sessions'
